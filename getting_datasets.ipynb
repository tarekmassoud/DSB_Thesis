# %%
import pandas as pd
pd.set_option('display.max_columns', None)

import warnings
warnings.simplefilter("ignore", UserWarning)

# %%
df_2013 = pd.read_excel('data/ATP_2013.xlsx')
df_2014 = pd.read_excel('data/ATP_2014.xlsx')
df_2015 = pd.read_excel('data/ATP_2015.xlsx')
df_2016 = pd.read_excel('data/ATP_2016.xlsx')
df_2017 = pd.read_excel('data/ATP_2017.xlsx')
df_2018 = pd.read_excel('data/ATP_2018.xlsx')
df_2019 = pd.read_excel('data/ATP_2019.xlsx')
df_2020 = pd.read_excel('data/ATP_2020.xlsx')
df_2021 = pd.read_excel('data/ATP_2021.xlsx')
df_2022 = pd.read_excel('data/ATP_2022.xlsx')
df_2023 = pd.read_excel('data/ATP_2023.xlsx')
df_2024 = pd.read_excel('data/ATP_2024.xlsx')

# %%
df_2024.head()
# Out:
#    ATP  Location              Tournament       Date  Series    Court Surface  \
# 0    1  Brisbane  Brisbane International 2023-12-31  ATP250  Outdoor    Hard
# 1    1  Brisbane  Brisbane International 2023-12-31  ATP250  Outdoor    Hard
# 2    1  Brisbane  Brisbane International 2024-01-01  ATP250  Outdoor    Hard
# 3    1  Brisbane  Brisbane International 2024-01-01  ATP250  Outdoor    Hard
# 4    1  Brisbane  Brisbane International 2024-01-01  ATP250  Outdoor    Hard
#
#        Round  Best of         Winner          Loser  WRank  LRank  WPts  \
# 0  1st Round        3     Popyrin A.   O Connell C.     40   68.0  1084
# 1  1st Round        3  Shevchenko A.  Van Assche L.     48   90.0   947
# 2  1st Round        3   Safiullin R.     Shelton B.     39   17.0  1122
# 3  1st Round        3        Rune H.     Purcell M.      8   45.0  3660
# 4  1st Round        3    Dimitrov G.      Murray A.     14   42.0  2570
#
#      LPts   W1   L1   W2   L2   W3   L3  W4  L4  W5  L5  Wsets  Lsets  \
# 0   780.0  6.0  4.0  6.0  7.0  7.0  6.0 NaN NaN NaN NaN    2.0    1.0
# 1   687.0  6.0  3.0  6.0  2.0  NaN  NaN NaN NaN NaN NaN    2.0    0.0
# 2  2145.0  6.0  3.0  6.0  7.0  6.0  3.0 NaN NaN NaN NaN    2.0    1.0
# 3  1012.0  4.0  6.0  6.0  4.0  6.0  2.0 NaN NaN NaN NaN    2.0    1.0
# 4  1050.0  4.0  6.0  7.0  5.0  6.0  2.0 NaN NaN NaN NaN    2.0    1.0
#
#      Comment  B365W  B365L   PSW   PSL  MaxW  MaxL  AvgW  AvgL
# 0  Completed   1.62   2.30  1.72  2.23  1.77  2.32  1.68  2.17
# 1  Completed   1.62   2.30  1.78  2.14  1.78  2.32  1.70  2.14
# 2  Completed   2.30   1.62  2.31  1.68  2.32  1.68  2.24  1.63
# 3  Completed   1.25   4.00  1.32  3.68  1.32  4.01  1.28  3.65
# 4  Completed   1.33   3.40  1.35  3.47  1.36  3.50  1.33  3.25

# %%
# List of all the dataframes
dfs = [
    df_2013, df_2014, df_2015, 
    df_2016, df_2017, df_2018, 
    df_2019, df_2020, df_2021, 
    df_2022, df_2023, df_2024
]

# Concatenate all dataframes along the rows 
df_final = pd.concat(dfs, ignore_index=True)

# # Sort the DataFrame by the Date column
# df_final['Date'] = pd.to_datetime(df_final['Date']) 
# df_final = df_final.sort_values(by='Date', ascending=True)

# Reset index after sorting
df_final = df_final.reset_index(drop=True)

# %%
df_final.head()
# Out:
#    ATP  Location              Tournament       Date  Series    Court Surface  \
# 0    1  Brisbane  Brisbane International 2012-12-31  ATP250  Outdoor    Hard
# 1    1  Brisbane  Brisbane International 2012-12-31  ATP250  Outdoor    Hard
# 2    1  Brisbane  Brisbane International 2012-12-31  ATP250  Outdoor    Hard
# 3    1  Brisbane  Brisbane International 2012-12-31  ATP250  Outdoor    Hard
# 4    1  Brisbane  Brisbane International 2013-01-01  ATP250  Outdoor    Hard
#
#        Round  Best of        Winner         Loser  WRank  LRank    WPts  \
# 0  1st Round      3.0      Mayer F.    Giraldo S.   28.0   57.0  1215.0
# 1  1st Round      3.0   Nieminen J.  Benneteau J.   41.0   35.0   927.0
# 2  1st Round      3.0  Nishikori K.  Matosevic M.   19.0   49.0  1830.0
# 3  1st Round      3.0  Baghdatis M.   Mitchell B.   36.0  326.0  1070.0
# 4  1st Round      3.0    Istomin D.     Klizan M.   43.0   30.0   897.0
#
#      LPts   W1   L1   W2   L2   W3   L3  W4  L4  W5  L5  Wsets  Lsets  \
# 0   778.0  6.0  4.0  6.0  4.0  NaN  NaN NaN NaN NaN NaN    2.0    0.0
# 1  1075.0  6.0  3.0  2.0  6.0  6.0  1.0 NaN NaN NaN NaN    2.0    1.0
# 2   845.0  7.0  5.0  6.0  2.0  NaN  NaN NaN NaN NaN NaN    2.0    0.0
# 3   137.0  6.0  4.0  6.0  4.0  NaN  NaN NaN NaN NaN NaN    2.0    0.0
# 4  1175.0  6.0  1.0  6.0  2.0  NaN  NaN NaN NaN NaN NaN    2.0    0.0
#
#      Comment  B365W  B365L   EXW   EXL   LBW   LBL   PSW   PSL   SJW   SJL  \
# 0  Completed   1.36   3.00  1.45  2.65  1.44  2.62  1.47  2.85  1.44  2.63
# 1  Completed   1.61   2.20  1.75  2.00  1.80  1.91  1.80  2.10  1.73  2.00
# 2  Completed   1.25   3.75  1.25  3.75  1.29  3.50  1.30  3.85  1.30  3.20
# 3  Completed   1.07   9.00  1.06  8.00  1.08  7.00  1.08  9.43  1.07  7.00
# 4  Completed   1.90   1.80  1.87  1.87  1.91  1.80  1.88  2.00  1.91  1.80
#
#    MaxW  MaxL  AvgW  AvgL
# 0  1.47  3.20  1.42  2.78
# 1  1.80  2.26  1.73  2.05
# 2  1.30  4.20  1.28  3.58
# 3  1.10  9.50  1.08  7.76
# 4  2.05  2.00  1.88  1.85
